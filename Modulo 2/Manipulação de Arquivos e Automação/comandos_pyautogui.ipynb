# %% [markdown]
# # PyAutoGui

# %% [markdown]
# O PyAutoGUI é uma biblioteca Python que permite automatizar ações do teclado e do mouse. Com ela, você pode simular cliques, digitação, movimentos do cursor e até tirar capturas de tela.
#
# É como um robô controlado por Python, que faz o que você mandaria seu mouse ou teclado fazer — só que automaticamente.

# %% [markdown]
# #  O que é possível fazer com PyAutoGUI?

# %% [markdown]
# Com o PyAutoGUI, você pode:
#
# - Mover o mouse para qualquer parte da tela
# - Clicar, clicar duplo ou clicar com o botão direito
# - Digitar texto automaticamente
# - Apertar teclas do teclado (como Enter, Ctrl, Esc...)
# - Capturar a tela (screenshot)
# - Criar bots simples para jogos, automatizar tarefas repetitivas, preencher formulários etc.

# %% [markdown]
# ## ❌ Limitações do PyAutoGUI
# Apesar de útil, o PyAutoGUI tem algumas limitações:
#
# Não interage diretamente com o conteúdo da tela (ele não “entende” o que está vendo).
#
# É sensível a mudanças na tela: se a posição ou imagem mudar, o script pode falhar.
#
# Não funciona bem em ambientes que usam proteção contra automação (como certos jogos ou apps de segurança).
#
# Pode ser bloqueado por antivírus ou firewalls.
#
# Não é o ideal para automações complexas (para isso, outras ferramentas como Selenium, Pywinauto ou AutoHotkey podem ser melhores).

# %% [markdown]
# ## 📋 Tabela com Principais Comandos do PyAutoGUI

# %% [markdown]
# | Comando                         | O que faz                                | Exemplo                       |
# | ------------------------------- | ---------------------------------------- | ----------------------------- |
# | `pyautogui.moveTo(x, y)`        | Move o mouse para a posição (x, y)       | `moveTo(500, 300)`            |
# | `pyautogui.click()`             | Clica na posição atual do mouse          | `click()`                     |
# | `pyautogui.click(x, y)`         | Clica na posição (x, y)                  | `click(400, 500)`             |
# | `pyautogui.doubleClick()`       | Clica duas vezes rapidamente             | `doubleClick()`               |
# | `pyautogui.rightClick()`        | Clica com o botão direito do mouse       | `rightClick()`                |
# | `pyautogui.write(text)`     | Digita um texto como se fosse no teclado | `typewrite("Olá mundo")`      |
# | `pyautogui.press('enter')`      | Pressiona uma tecla específica           | `press('enter')`              |
# | `pyautogui.hotkey('ctrl', 's')` | Pressiona um atalho de teclas            | `hotkey('ctrl', 's')`         |
# | `pyautogui.screenshot()`        | Tira um print da tela                    | `screenshot("imagem.png")`    |
# | `pyautogui.locateOnScreen()`    | Procura uma imagem na tela               | `locateOnScreen("botao.png")` |

# %% [markdown]
# import pyautogui as aut
# aut.press("win")
# aut.write("Bloco de notas",interval=0.5)
# aut.press("enter",interval=0.5)
# aut.press("enter")
# aut.write("Veio até mim Com passos suaves Que eu nem ouvi Se aproximou Com Tuas mãos me tocou Então olhando dentro dos meus olhos Enxergou o que eu nunca vi, não E com amor me disse Que se tudo acabasse Estaria aqui  Estaria aqui Estaria aqui  Jesus, as estações mudaram, mas Você Continua surpreendendo Sendo o mesmo desde sempre Meu amor Eu guardo ele todo só pra Ti Pois é o melhor que eu posso Te dar Meu coração é só Teu  Desde que Você chegou Tudo novo se fez",interval=0.2)

# %%
import pyautogui as aut
aut.press("win")
aut.write("Bloco de notas",interval=0.5)
aut.press("enter",interval=0.5)
aut.press("enter")
aut.write("Veio até mim Com passos suaves Que eu nem ouvi Se aproximou Com Tuas mãos me tocou Então olhando dentro dos meus olhos Enxergou o que eu nunca vi, não E com amor me disse Que se tudo acabasse Estaria aqui  Estaria aqui Estaria aqui  Jesus, as estações mudaram, mas Você Continua surpreendendo Sendo o mesmo desde sempre Meu amor Eu guardo ele todo só pra Ti Pois é o melhor que eu posso Te dar Meu coração é só Teu  Desde que Você chegou Tudo novo se fez",interval=0.2)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 aut.press("win")
#       3 aut.write("Bloco de notas",interval=0.5)
#       4 aut.press("enter",interval=0.5)
#       5 aut.press("enter")
# ----> 6 aut.write("Veio até mim Com passos suaves Que eu nem ouvi Se aproximou Com Tuas mãos me tocou Então olhando dentro dos meus olhos Enxergou o que eu nunca vi, não E com amor me disse Que se tudo acabasse Estaria aqui  Estaria aqui Estaria aqui  Jesus, as estações mudaram, mas Você Continua surpreendendo Sendo o mesmo desde sempre Meu amor Eu guardo ele todo só pra Ti Pois é o melhor que eu posso Te dar Meu coração é só Teu  Desde que Você chegou Tudo novo se fez",interval=0.2)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyautogui\__init__.py:594, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
#     593     failSafeCheck()
# --> 594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#     596     return returnVal
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyautogui\__init__.py:1687, in typewrite(message, interval, logScreenshot, _pause)
#    1685 press(c, _pause=False)
#    1686 time.sleep(interval)
# -> 1687 failSafeCheck()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
#    1733     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1734         raise FailSafeException(
#    1735             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1736         )
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
aut.hotkey("alt", "f4")

# %%
import pyautogui as aut

# %%
aut.hotkey("win", "r")
aut.write("chrome")
aut.sleep(0.5)
aut.press("enter")
### esperar um segundo
aut.sleep(1)
aut.write("Cabeça de Bagre")
aut.sleep(1)
aut.press("enter")

# %% [markdown]
# pyautogui.mouseInfo()

# %%
aut.mouseInfo()

# %%
aut.moveTo(1717,121)
aut.click
# Out:
# <function pyautogui.click(x=None, y=None, clicks=1, interval=0.0, button='primary', duration=0.0, tween=<function linear at 0x00000159BEFFEE80>, logScreenshot=None, _pause=True)>

# %%
aut.hotkey("win", "r")
aut.write("chrome")
aut.sleep(0.5)
aut.press("enter")
aut.sleep(1)
aut.write("sobre as aguas - dunamis")
aut.sleep(1)
aut.press("enter")
aut.sleep(1)
aut.moveTo(256,283)
aut.click(256,283)

# %%
aut.hotkey("win", "r")
aut.write("chrome")
aut.sleep(0.5)
aut.press("enter")
aut.sleep(1)
aut.write("Youtube")
aut.press("enter")
aut.sleep(1)
aut.moveTo(287,306)
aut.click(287,306)
aut.sleep(3)
aut.moveTo(712,109)
aut.click(712,109)
aut.write("sobre as aguas dunamis movement")
aut.sleep(3)
aut.moveTo(757,657)
aut.click(757,657)
